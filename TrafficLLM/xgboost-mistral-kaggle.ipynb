# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/kaggle/input/congestion-data/us_congestion_2016_2022_sample_2m.csv')

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error, accuracy_score

# %%
df = df.drop(["Description", "Street", "City", "County", "State", "Country", "ZipCode", "LocalTimeZone",
               "WeatherStation_AirportCode", "WeatherTimeStamp","ID"], axis=1, errors="ignore")

# %%
df_original = pd.read_csv('/kaggle/input/congestion-data/us_congestion_2016_2022_sample_2m.csv')

# %%
encoding_maps = {}

# %%
categorical_cols = ["Weather_Event", "Weather_Conditions", "WindDir","Congestion_Speed"]
for col in categorical_cols:
    encoder = LabelEncoder()
    encoder.fit(df_original[col].astype(str))  # Fit on the original unencoded data
    encoding_maps[col] = dict(zip(encoder.classes_, encoder.transform(encoder.classes_)))  # Store mapping

# %%
categorical_cols = ["Weather_Event", "Weather_Conditions", "WindDir","Congestion_Speed"]
for col in categorical_cols:
    df[col] = LabelEncoder().fit_transform(df[col].astype(str))

# %%
weather_conditions_map = encoding_maps["Weather_Conditions"]
print(weather_conditions_map)
# Out:
# {'Blowing Dust': 0, 'Blowing Dust / Windy': 1, 'Blowing Sand': 2, 'Blowing Snow': 3, 'Blowing Snow / Windy': 4, 'Blowing Snow Nearby': 5, 'Blowing Snow Nearby / Windy': 6, 'Clear': 7, 'Cloudy': 8, 'Cloudy / Windy': 9, 'Drifting Snow': 10, 'Drizzle': 11, 'Drizzle / Windy': 12, 'Drizzle and Fog': 13, 'Fair': 14, 'Fair / Windy': 15, 'Fog': 16, 'Fog / Windy': 17, 'Freezing Drizzle': 18, 'Freezing Rain': 19, 'Freezing Rain / Windy': 20, 'Funnel Cloud': 21, 'Hail': 22, 'Haze': 23, 'Haze / Windy': 24, 'Heavy Blowing Snow': 25, 'Heavy Drizzle': 26, 'Heavy Freezing Drizzle': 27, 'Heavy Freezing Rain': 28, 'Heavy Ice Pellets': 29, 'Heavy Rain': 30, 'Heavy Rain / Windy': 31, 'Heavy Rain Shower': 32, 'Heavy Rain Showers': 33, 'Heavy Sleet': 34, 'Heavy Sleet / Windy': 35, 'Heavy Sleet and Thunder': 36, 'Heavy Snow': 37, 'Heavy Snow / Windy': 38, 'Heavy Snow Showers': 39, 'Heavy Snow with Thunder': 40, 'Heavy T-Storm': 41, 'Heavy T-Storm / Windy': 42, 'Heavy Thunderstorm': 43, 'Heavy Thunderstorms and Rain': 44, 'Heavy Thunderstorms and Snow': 45, 'Heavy Thunderstorms with Hail': 46, 'Heavy Thunderstorms with Ice Pellets': 47, 'Ice Crystals': 48, 'Ice Pellets': 49, 'Light Blowing Snow': 50, 'Light Drizzle': 51, 'Light Drizzle / Windy': 52, 'Light Freezing Drizzle': 53, 'Light Freezing Fog': 54, 'Light Freezing Rain': 55, 'Light Freezing Rain / Windy': 56, 'Light Ice Pellet Showers': 57, 'Light Ice Pellets': 58, 'Light Rain': 59, 'Light Rain / Windy': 60, 'Light Rain Shower': 61, 'Light Rain Shower / Windy': 62, 'Light Rain Showers': 63, 'Light Rain with Thunder': 64, 'Light Sleet': 65, 'Light Sleet / Windy': 66, 'Light Sleet and Thunder': 67, 'Light Snow': 68, 'Light Snow / Windy': 69, 'Light Snow Grains': 70, 'Light Snow Grains / Windy': 71, 'Light Snow Shower': 72, 'Light Snow Shower / Windy': 73, 'Light Snow Showers': 74, 'Light Snow and Sleet': 75, 'Light Snow and Sleet / Windy': 76, 'Light Snow with Thunder': 77, 'Light Thunderstorm': 78, 'Light Thunderstorms and Ice Pellets': 79, 'Light Thunderstorms and Rain': 80, 'Light Thunderstorms and Snow': 81, 'Low Drifting Snow': 82, 'Mist': 83, 'Mist / Windy': 84, 'Mostly Cloudy': 85, 'Mostly Cloudy / Windy': 86, 'N/A Precipitation': 87, 'Overcast': 88, 'Partial Fog': 89, 'Partly Cloudy': 90, 'Partly Cloudy / Windy': 91, 'Patches of Fog': 92, 'Rain': 93, 'Rain / Windy': 94, 'Rain Shower': 95, 'Rain Shower / Windy': 96, 'Rain Showers': 97, 'Sand': 98, 'Sand / Dust Whirls Nearby': 99, 'Sand / Dust Whirlwinds': 100, 'Sandstorm': 101, 'Scattered Clouds': 102, 'Shallow Fog': 103, 'Showers in the Vicinity': 104, 'Sleet': 105, 'Sleet / Windy': 106, 'Sleet and Thunder': 107, 'Small Hail': 108, 'Smoke': 109, 'Smoke / Windy': 110, 'Snow': 111, 'Snow / Windy': 112, 'Snow Showers': 113, 'Snow and Sleet': 114, 'Snow and Sleet / Windy': 115, 'Snow and Thunder': 116, 'Snow and Thunder / Windy': 117, 'Squalls': 118, 'Squalls / Windy': 119, 'T-Storm': 120, 'T-Storm / Windy': 121, 'Thunder': 122, 'Thunder / Windy': 123, 'Thunder / Wintry Mix': 124, 'Thunder and Hail': 125, 'Thunder and Hail / Windy': 126, 'Thunder and Small Hail': 127, 'Thunder in the Vicinity': 128, 'Thunderstorm': 129, 'Thunderstorms and Ice Pellets': 130, 'Thunderstorms and Rain': 131, 'Thunderstorms and Snow': 132, 'Volcanic Ash': 133, 'Widespread Dust': 134, 'Widespread Dust / Windy': 135, 'Wintry Mix': 136, 'Wintry Mix / Windy': 137, 'nan': 138}

# %%
df["StartTime"] = pd.to_datetime(df["StartTime"], utc=True, errors="coerce")
df["EndTime"] = pd.to_datetime(df["EndTime"], utc=True, errors="coerce")

# %%
df = df.dropna(subset=["StartTime", "EndTime"])

# %%
df["StartTime"] = (df["StartTime"] - df["StartTime"].min()).dt.total_seconds()
df["EndTime"] = (df["EndTime"] - df["EndTime"].min()).dt.total_seconds()

# %%
X = df.drop(["DelayFromTypicalTraffic(mins)", "Congestion_Speed"], axis=1)
y_regression = df["DelayFromTypicalTraffic(mins)"]  # Regression target
y_classification = df["Congestion_Speed"]  # Binary Classification (0 = Fast, 1 = Moderate, 2 = Slow)

# %%
X_train, X_test, y_reg_train, y_reg_test, y_cls_train, y_cls_test = train_test_split(
    X, y_regression, y_classification, test_size=0.2, random_state=42
)

# %%
model = xgb.XGBRegressor(objective="reg:squarederror", enable_categorical=True)
clf = xgb.XGBClassifier(objective="binary:logistic", enable_categorical=True)

# %%
model.fit(X_train, y_reg_train)
clf.fit(X_train, y_cls_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_reg_pred = model.predict(X_test)
y_cls_pred = clf.predict(X_test)

# %%
mae = mean_absolute_error(y_reg_test, y_reg_pred)
accuracy = accuracy_score(y_cls_test, y_cls_pred)

print(f"Mean Absolute Error (MAE) for Delay Prediction: {mae}")
print(f"Accuracy for Congestion Prediction: {accuracy}")
# Out:
# Mean Absolute Error (MAE) for Delay Prediction: 0.7487718644020829
# Accuracy for Congestion Prediction: 0.7246844628612037

# %%
from sklearn.metrics import classification_report
print(classification_report(y_cls_test, y_cls_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.74      0.77    143084
#            1       0.67      0.74      0.70    159343
#            2       0.71      0.68      0.70     97209
#
#     accuracy                           0.72    399636
#    macro avg       0.73      0.72      0.72    399636
# weighted avg       0.73      0.72      0.73    399636

# %%
importance = model.feature_importances_
for feature, score in zip(X_train.columns, importance):
    print(f"{feature}: {score:.4f}")
# Out:
# Severity: 0.0288
# Start_Lat: 0.0275
# Start_Lng: 0.0342
# StartTime: 0.0393
# EndTime: 0.0543
# Distance(mi): 0.0496
# DelayFromFreeFlowSpeed(mins): 0.5441
# Temperature(F): 0.0516
# WindChill(F): 0.0228
# Humidity(%): 0.0216
# Pressure(in): 0.0230
# Visibility(mi): 0.0209
# WindDir: 0.0156
# WindSpeed(mph): 0.0116
# Precipitation(in): 0.0163
# Weather_Event: 0.0257
# Weather_Conditions: 0.0131

# %%
import optuna

# %%
def objective(trial):
    params = {
        "objective": "reg:squarederror",  # Regression for DelayFromTypicalTraffic
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000, step=100),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 1.0),
        "reg_lambda": trial.suggest_float("reg_lambda", 0.0, 1.0),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
    }

    # Train model with current parameters
    model = xgb.XGBRegressor(**params)
    model.fit(X_train, y_reg_train)

    # Predict and evaluate
    y_pred = model.predict(X_test)
    mae = mean_absolute_error(y_reg_test, y_pred)

    return mae  # Optuna minimizes this

# %%
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=30)
# Out:
# [I 2025-03-03 15:33:06,277] A new study created in memory with name: no-name-97d5e6a9-eddd-40ed-b8ba-d14e62c95662
# [I 2025-03-03 15:34:14,749] Trial 0 finished with value: 0.7884443106836089 and parameters: {'n_estimators': 900, 'max_depth': 5, 'learning_rate': 0.01842132618982219, 'subsample': 0.9468920920110832, 'colsample_bytree': 0.7268331130027608, 'reg_alpha': 0.14439331954332535, 'reg_lambda': 0.8836715108124366, 'min_child_weight': 2}. Best is trial 0 with value: 0.7884443106836089.
# [I 2025-03-03 15:35:41,392] Trial 1 finished with value: 0.7081139886267813 and parameters: {'n_estimators': 500, 'max_depth': 11, 'learning_rate': 0.21171462370255129, 'subsample': 0.6082622759734102, 'colsample_bytree': 0.68637915938959, 'reg_alpha': 0.28026193728143656, 'reg_lambda': 0.419512342645055, 'min_child_weight': 6}. Best is trial 1 with value: 0.7081139886267813.
# [I 2025-03-03 15:36:49,504] Trial 2 finished with value: 0.7243212898066591 and parameters: {'n_estimators': 700, 'max_depth': 7, 'learning_rate': 0.04527992033390985, 'subsample': 0.724976698044565, 'colsample_bytree': 0.9695015797546769, 'reg_alpha': 0.253167739630219, 'reg_lambda': 0.5341021695216972, 'min_child_weight': 5}. Best is trial 1 with value: 0.7081139886267813.
# [I 2025-03-03 15:37:33,106] Trial 3 finished with value: 0.8118644653042152 and parameters: {'n_estimators': 700, 'max_depth': 4, 'learning_rate': 0.033786983053371605, 'subsample': 0.5556476458308292, 'colsample_bytree': 0.544603932431087, 'reg_alpha': 0.7617102847420688, 'reg_lambda': 0.22420484768734772, 'min_child_weight': 6}. Best is trial 1 with value: 0.7081139886267813.
# [I 2025-03-03 15:39:24,593] Trial 4 finished with value: 0.7082982340491873 and parameters: {'n_estimators': 400, 'max_depth': 12, 'learning_rate': 0.016562619340106933, 'subsample': 0.8193532649255733, 'colsample_bytree': 0.6980733462522699, 'reg_alpha': 0.09733625187940476, 'reg_lambda': 0.6116203684685627, 'min_child_weight': 9}. Best is trial 1 with value: 0.7081139886267813.
# [I 2025-03-03 15:39:32,932] Trial 5 finished with value: 1.2517815320117847 and parameters: {'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.019445009807297953, 'subsample': 0.6699235659602373, 'colsample_bytree': 0.8521202321877739, 'reg_alpha': 0.980951678968897, 'reg_lambda': 0.8167543557588202, 'min_child_weight': 4}. Best is trial 1 with value: 0.7081139886267813.
# [I 2025-03-03 15:40:44,188] Trial 6 finished with value: 0.7602519017062122 and parameters: {'n_estimators': 800, 'max_depth': 6, 'learning_rate': 0.024340248233821072, 'subsample': 0.9620329312158274, 'colsample_bytree': 0.6133690233022908, 'reg_alpha': 0.5666964753534635, 'reg_lambda': 0.9816030928297348, 'min_child_weight': 8}. Best is trial 1 with value: 0.7081139886267813.
# [I 2025-03-03 15:42:38,499] Trial 7 finished with value: 0.6697060567782771 and parameters: {'n_estimators': 500, 'max_depth': 12, 'learning_rate': 0.07324639518395248, 'subsample': 0.5863383114713837, 'colsample_bytree': 0.9426269475099298, 'reg_alpha': 0.7193287856789722, 'reg_lambda': 0.10395898140009008, 'min_child_weight': 2}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 15:44:02,652] Trial 8 finished with value: 0.6977304010179015 and parameters: {'n_estimators': 400, 'max_depth': 11, 'learning_rate': 0.02701842809454014, 'subsample': 0.7557248352597392, 'colsample_bytree': 0.9377399906893571, 'reg_alpha': 0.9102013475156766, 'reg_lambda': 0.7280307403950245, 'min_child_weight': 10}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 15:47:00,076] Trial 9 finished with value: 0.6982189380937479 and parameters: {'n_estimators': 600, 'max_depth': 12, 'learning_rate': 0.013090032276154346, 'subsample': 0.7909405387693349, 'colsample_bytree': 0.7452892290427692, 'reg_alpha': 0.3361224075771557, 'reg_lambda': 0.5771476637893354, 'min_child_weight': 3}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 15:47:18,319] Trial 10 finished with value: 0.7321164476732143 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.11663768990298282, 'subsample': 0.50115160629966, 'colsample_bytree': 0.8501041007258662, 'reg_alpha': 0.6285441022669563, 'reg_lambda': 0.022539807926444833, 'min_child_weight': 1}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 15:48:04,810] Trial 11 finished with value: 0.7023393372978858 and parameters: {'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.07816279919617491, 'subsample': 0.8508689206925901, 'colsample_bytree': 0.9986307994394643, 'reg_alpha': 0.9364774890413012, 'reg_lambda': 0.02141148547137972, 'min_child_weight': 10}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 15:48:54,557] Trial 12 finished with value: 0.694138755138084 and parameters: {'n_estimators': 300, 'max_depth': 10, 'learning_rate': 0.07342685792887443, 'subsample': 0.683163187945697, 'colsample_bytree': 0.8880106232907071, 'reg_alpha': 0.7782794211905059, 'reg_lambda': 0.31453781029413275, 'min_child_weight': 8}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 15:49:38,098] Trial 13 finished with value: 0.7077851814804258 and parameters: {'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.07638088582775264, 'subsample': 0.6451318931012455, 'colsample_bytree': 0.8731606004922304, 'reg_alpha': 0.7314519360766105, 'reg_lambda': 0.2662720594509281, 'min_child_weight': 7}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 15:50:09,853] Trial 14 finished with value: 0.7019301093934952 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.15065853157133108, 'subsample': 0.5730180019723925, 'colsample_bytree': 0.9121547949962057, 'reg_alpha': 0.795254193848176, 'reg_lambda': 0.1953157785681192, 'min_child_weight': 8}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 15:51:57,591] Trial 15 finished with value: 0.6961941388934086 and parameters: {'n_estimators': 1000, 'max_depth': 8, 'learning_rate': 0.06412799347804868, 'subsample': 0.6941378942238858, 'colsample_bytree': 0.7984170802148578, 'reg_alpha': 0.4344952934616748, 'reg_lambda': 0.3478810330945715, 'min_child_weight': 1}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 15:53:26,074] Trial 16 finished with value: 0.6861774252331627 and parameters: {'n_estimators': 500, 'max_depth': 11, 'learning_rate': 0.10467296800655043, 'subsample': 0.5180667441138121, 'colsample_bytree': 0.8123483272316794, 'reg_alpha': 0.6160142430185674, 'reg_lambda': 0.12900117796915267, 'min_child_weight': 4}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 15:55:16,367] Trial 17 finished with value: 0.7575719825386806 and parameters: {'n_estimators': 500, 'max_depth': 12, 'learning_rate': 0.2771822928888759, 'subsample': 0.5034052818598489, 'colsample_bytree': 0.8079343679099028, 'reg_alpha': 0.47596644620774325, 'reg_lambda': 0.12492751065402553, 'min_child_weight': 3}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 15:57:02,917] Trial 18 finished with value: 0.6828877380229122 and parameters: {'n_estimators': 600, 'max_depth': 11, 'learning_rate': 0.11367078907961657, 'subsample': 0.5576480012695452, 'colsample_bytree': 0.8074901568660962, 'reg_alpha': 0.6078163387708477, 'reg_lambda': 0.10504386216379324, 'min_child_weight': 4}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 15:58:12,943] Trial 19 finished with value: 0.7289958319958927 and parameters: {'n_estimators': 700, 'max_depth': 7, 'learning_rate': 0.04713378881481143, 'subsample': 0.6077002523516294, 'colsample_bytree': 0.6357931510546982, 'reg_alpha': 0.6916930695691946, 'reg_lambda': 0.46022057374106673, 'min_child_weight': 2}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 16:00:02,877] Trial 20 finished with value: 0.684780275693486 and parameters: {'n_estimators': 600, 'max_depth': 11, 'learning_rate': 0.1620441157180355, 'subsample': 0.615418632608577, 'colsample_bytree': 0.9697437247079923, 'reg_alpha': 0.8574757596115153, 'reg_lambda': 0.11300327333935666, 'min_child_weight': 4}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 16:01:34,695] Trial 21 finished with value: 0.6843797412291672 and parameters: {'n_estimators': 600, 'max_depth': 10, 'learning_rate': 0.15173649265223607, 'subsample': 0.6160171961550861, 'colsample_bytree': 0.9476466891630174, 'reg_alpha': 0.8475842602357713, 'reg_lambda': 0.1149822914766016, 'min_child_weight': 4}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 16:03:33,717] Trial 22 finished with value: 0.6827399539963958 and parameters: {'n_estimators': 800, 'max_depth': 10, 'learning_rate': 0.11003526586092226, 'subsample': 0.5617735327695543, 'colsample_bytree': 0.9289180539106051, 'reg_alpha': 0.5455978663307833, 'reg_lambda': 0.002474956190116992, 'min_child_weight': 5}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 16:06:22,721] Trial 23 finished with value: 0.6761180401975375 and parameters: {'n_estimators': 800, 'max_depth': 12, 'learning_rate': 0.10338268014646892, 'subsample': 0.5565269007262869, 'colsample_bytree': 0.9122677981879523, 'reg_alpha': 0.5342533492922052, 'reg_lambda': 0.016354123064849763, 'min_child_weight': 5}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 16:09:31,258] Trial 24 finished with value: 0.6745668634988202 and parameters: {'n_estimators': 900, 'max_depth': 12, 'learning_rate': 0.09511826894067393, 'subsample': 0.5557409730739246, 'colsample_bytree': 0.9104796059244282, 'reg_alpha': 0.3991017160581002, 'reg_lambda': 0.004939626970758559, 'min_child_weight': 5}. Best is trial 7 with value: 0.6697060567782771.
# [I 2025-03-03 16:12:57,966] Trial 25 finished with value: 0.6674509989046638 and parameters: {'n_estimators': 1000, 'max_depth': 12, 'learning_rate': 0.054002027801447965, 'subsample': 0.5370371393943092, 'colsample_bytree': 0.9998897532814033, 'reg_alpha': 0.4058842023197334, 'reg_lambda': 0.21467834716377823, 'min_child_weight': 6}. Best is trial 25 with value: 0.6674509989046638.
# [I 2025-03-03 16:16:24,002] Trial 26 finished with value: 0.6559374319882515 and parameters: {'n_estimators': 1000, 'max_depth': 12, 'learning_rate': 0.040380241708164524, 'subsample': 0.8966136021446779, 'colsample_bytree': 0.9848578447533113, 'reg_alpha': 0.3542898394473588, 'reg_lambda': 0.1951372898462458, 'min_child_weight': 7}. Best is trial 26 with value: 0.6559374319882515.
# [I 2025-03-03 16:18:15,541] Trial 27 finished with value: 0.7025910363011847 and parameters: {'n_estimators': 1000, 'max_depth': 8, 'learning_rate': 0.03445977349230863, 'subsample': 0.9015479158456128, 'colsample_bytree': 0.9801107315020179, 'reg_alpha': 0.1988169871040544, 'reg_lambda': 0.3778319095034607, 'min_child_weight': 7}. Best is trial 26 with value: 0.6559374319882515.
# [I 2025-03-03 16:21:07,774] Trial 28 finished with value: 0.653894843878839 and parameters: {'n_estimators': 900, 'max_depth': 12, 'learning_rate': 0.05343119005856983, 'subsample': 0.897285760757781, 'colsample_bytree': 0.9980782272439057, 'reg_alpha': 0.018441364690612083, 'reg_lambda': 0.19361190668945039, 'min_child_weight': 6}. Best is trial 28 with value: 0.653894843878839.
# [I 2025-03-03 16:22:08,937] Trial 29 finished with value: 0.749264359078628 and parameters: {'n_estimators': 900, 'max_depth': 5, 'learning_rate': 0.05238190679738722, 'subsample': 0.9972652100151229, 'colsample_bytree': 0.9987246694403485, 'reg_alpha': 0.009212282515812862, 'reg_lambda': 0.266396046929781, 'min_child_weight': 7}. Best is trial 28 with value: 0.653894843878839.

# %%
best_params = study.best_params
print("Best parameters:", best_params)
# Out:
# Best parameters: {'n_estimators': 900, 'max_depth': 12, 'learning_rate': 0.05343119005856983, 'subsample': 0.897285760757781, 'colsample_bytree': 0.9980782272439057, 'reg_alpha': 0.018441364690612083, 'reg_lambda': 0.19361190668945039, 'min_child_weight': 6}

# %%
best_model = xgb.XGBRegressor(**best_params)
best_model.fit(X_train, y_reg_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9980782272439057, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05343119005856983, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=12, max_leaves=None,
#              min_child_weight=6, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=900, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred_final = best_model.predict(X_test)
mae_final = mean_absolute_error(y_reg_test, y_pred_final)

# %%
print(f"Final Mean Absolute Error (MAE): {mae_final}")
# Out:
# Final Mean Absolute Error (MAE): 0.653894843878839

# %%
def objective_cls(trial):
    params = {
        "objective": "multi:softmax",  # Multi-class classification
        "num_class": 3,  # 3 congestion levels
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000, step=100),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 1.0),
        "reg_lambda": trial.suggest_float("reg_lambda", 0.0, 1.0),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
    }

    clf = xgb.XGBClassifier(**params)
    clf.fit(X_train, y_cls_train)

    y_pred = clf.predict(X_test)
    acc = accuracy_score(y_cls_test, y_pred)

    return 1 - acc  # Optuna minimizes, so we minimize (1 - accuracy)

# %%
study_cls = optuna.create_study(direction="minimize")
study_cls.optimize(objective_cls, n_trials=30)
# Out:
# [I 2025-03-03 16:36:42,533] A new study created in memory with name: no-name-f3994644-e5a3-4f3a-b808-a4d59c092dd9
# [I 2025-03-03 16:40:58,724] Trial 0 finished with value: 0.27717723128046523 and parameters: {'n_estimators': 300, 'max_depth': 11, 'learning_rate': 0.013362835407451522, 'subsample': 0.6307269062478414, 'colsample_bytree': 0.9337203525709021, 'reg_alpha': 0.1890617755080245, 'reg_lambda': 0.6600169324590445, 'min_child_weight': 6}. Best is trial 0 with value: 0.27717723128046523.
# [I 2025-03-03 16:41:54,221] Trial 1 finished with value: 0.2623512396280615 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.24423659508830714, 'subsample': 0.6071485076343227, 'colsample_bytree': 0.7128083864813551, 'reg_alpha': 0.9571865408113802, 'reg_lambda': 0.010450057714587513, 'min_child_weight': 3}. Best is trial 1 with value: 0.2623512396280615.
# [I 2025-03-03 16:47:08,867] Trial 2 finished with value: 0.2516139687115275 and parameters: {'n_estimators': 500, 'max_depth': 11, 'learning_rate': 0.2079965679152174, 'subsample': 0.6380548007084117, 'colsample_bytree': 0.7835526163220384, 'reg_alpha': 0.9377821465222584, 'reg_lambda': 0.8920764213183769, 'min_child_weight': 5}. Best is trial 2 with value: 0.2516139687115275.
# [I 2025-03-03 16:48:19,358] Trial 3 finished with value: 0.27236285019367623 and parameters: {'n_estimators': 100, 'max_depth': 10, 'learning_rate': 0.07280620877817515, 'subsample': 0.5066879051821831, 'colsample_bytree': 0.7841009138717296, 'reg_alpha': 0.12130808033329887, 'reg_lambda': 0.43138873276891543, 'min_child_weight': 1}. Best is trial 2 with value: 0.2516139687115275.
# [I 2025-03-03 16:56:23,021] Trial 4 finished with value: 0.2683091613368165 and parameters: {'n_estimators': 600, 'max_depth': 11, 'learning_rate': 0.011078546486748294, 'subsample': 0.900636499808732, 'colsample_bytree': 0.9634304286923385, 'reg_alpha': 0.14518321235173137, 'reg_lambda': 0.03610764737056815, 'min_child_weight': 9}. Best is trial 2 with value: 0.2516139687115275.
# [I 2025-03-03 17:02:50,447] Trial 5 finished with value: 0.2665951015424036 and parameters: {'n_estimators': 500, 'max_depth': 11, 'learning_rate': 0.017295225011531076, 'subsample': 0.879017134838032, 'colsample_bytree': 0.5553178232747791, 'reg_alpha': 0.4804920432399141, 'reg_lambda': 0.2944530406342599, 'min_child_weight': 3}. Best is trial 2 with value: 0.2516139687115275.
# [I 2025-03-03 17:05:20,583] Trial 6 finished with value: 0.2556676575683873 and parameters: {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.26327617090667466, 'subsample': 0.6688439227851799, 'colsample_bytree': 0.9458455512102202, 'reg_alpha': 0.2966997945604323, 'reg_lambda': 0.9236009426141953, 'min_child_weight': 7}. Best is trial 2 with value: 0.2516139687115275.
# [I 2025-03-03 17:15:47,387] Trial 7 finished with value: 0.2479030918135503 and parameters: {'n_estimators': 900, 'max_depth': 12, 'learning_rate': 0.12827765048162765, 'subsample': 0.7148302394812658, 'colsample_bytree': 0.938303502163508, 'reg_alpha': 0.6623560032122159, 'reg_lambda': 0.5033333248655305, 'min_child_weight': 9}. Best is trial 7 with value: 0.2479030918135503.
# [I 2025-03-03 17:16:53,762] Trial 8 finished with value: 0.30201233122141147 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.010647130192138225, 'subsample': 0.998025325167962, 'colsample_bytree': 0.9403821318762448, 'reg_alpha': 0.270780140336472, 'reg_lambda': 0.36499360967944794, 'min_child_weight': 2}. Best is trial 7 with value: 0.2479030918135503.
# [I 2025-03-03 17:20:51,505] Trial 9 finished with value: 0.24714990641483747 and parameters: {'n_estimators': 400, 'max_depth': 11, 'learning_rate': 0.19691282737423993, 'subsample': 0.9079724348165712, 'colsample_bytree': 0.638472612249875, 'reg_alpha': 0.12309621035550145, 'reg_lambda': 0.1200956649083601, 'min_child_weight': 2}. Best is trial 9 with value: 0.24714990641483747.
# [I 2025-03-03 17:24:26,320] Trial 10 finished with value: 0.2964372579046932 and parameters: {'n_estimators': 800, 'max_depth': 4, 'learning_rate': 0.034724602119695906, 'subsample': 0.8224413404852295, 'colsample_bytree': 0.5076207710064465, 'reg_alpha': 0.5012040983442514, 'reg_lambda': 0.1662538133366422, 'min_child_weight': 4}. Best is trial 9 with value: 0.24714990641483747.
# [I 2025-03-03 17:30:26,675] Trial 11 finished with value: 0.25558007787086245 and parameters: {'n_estimators': 1000, 'max_depth': 7, 'learning_rate': 0.11001831456089474, 'subsample': 0.7606589831716414, 'colsample_bytree': 0.6616833991136248, 'reg_alpha': 0.6744394895529189, 'reg_lambda': 0.600218533283474, 'min_child_weight': 10}. Best is trial 9 with value: 0.24714990641483747.
# [I 2025-03-03 17:39:20,573] Trial 12 finished with value: 0.24692970603248954 and parameters: {'n_estimators': 800, 'max_depth': 12, 'learning_rate': 0.11217369281278339, 'subsample': 0.7366455708397992, 'colsample_bytree': 0.621938523406637, 'reg_alpha': 0.7274892210387098, 'reg_lambda': 0.7109795818967344, 'min_child_weight': 8}. Best is trial 12 with value: 0.24692970603248954.
# [I 2025-03-03 17:42:49,874] Trial 13 finished with value: 0.2829249617151608 and parameters: {'n_estimators': 700, 'max_depth': 5, 'learning_rate': 0.04926122951190854, 'subsample': 0.9981469904451199, 'colsample_bytree': 0.6187352217552107, 'reg_alpha': 0.014467703050624267, 'reg_lambda': 0.7478343630064532, 'min_child_weight': 7}. Best is trial 12 with value: 0.24692970603248954.
# [I 2025-03-03 17:46:26,097] Trial 14 finished with value: 0.24945450359827448 and parameters: {'n_estimators': 300, 'max_depth': 12, 'learning_rate': 0.11230871499052862, 'subsample': 0.7957595954594944, 'colsample_bytree': 0.6155701654912037, 'reg_alpha': 0.7733894364099042, 'reg_lambda': 0.778453218816348, 'min_child_weight': 7}. Best is trial 12 with value: 0.24692970603248954.
# [I 2025-03-03 17:51:45,983] Trial 15 finished with value: 0.24712988819826043 and parameters: {'n_estimators': 700, 'max_depth': 9, 'learning_rate': 0.16089006302406772, 'subsample': 0.9062350484095012, 'colsample_bytree': 0.7130253376389679, 'reg_alpha': 0.45931694797990785, 'reg_lambda': 0.19494765805247694, 'min_child_weight': 1}. Best is trial 12 with value: 0.24692970603248954.
# [I 2025-03-03 17:57:22,280] Trial 16 finished with value: 0.25360327898387536 and parameters: {'n_estimators': 800, 'max_depth': 8, 'learning_rate': 0.07196768686275033, 'subsample': 0.84651166492021, 'colsample_bytree': 0.853681814316183, 'reg_alpha': 0.5019039172209454, 'reg_lambda': 0.24836941331121418, 'min_child_weight': 8}. Best is trial 12 with value: 0.24692970603248954.
# [I 2025-03-03 18:01:13,604] Trial 17 finished with value: 0.2615204836401125 and parameters: {'n_estimators': 700, 'max_depth': 6, 'learning_rate': 0.15366991175838263, 'subsample': 0.7202379579771547, 'colsample_bytree': 0.7138964302004571, 'reg_alpha': 0.789993438453411, 'reg_lambda': 0.5472508183132839, 'min_child_weight': 5}. Best is trial 12 with value: 0.24692970603248954.
# [I 2025-03-03 18:05:00,817] Trial 18 finished with value: 0.3019097378614539 and parameters: {'n_estimators': 1000, 'max_depth': 3, 'learning_rate': 0.031174249216675633, 'subsample': 0.5489272602363706, 'colsample_bytree': 0.851712640973453, 'reg_alpha': 0.3859051867051617, 'reg_lambda': 0.7388427545521096, 'min_child_weight': 1}. Best is trial 12 with value: 0.24692970603248954.
# [I 2025-03-03 18:10:25,834] Trial 19 finished with value: 0.2534581469136915 and parameters: {'n_estimators': 700, 'max_depth': 9, 'learning_rate': 0.07894573877118742, 'subsample': 0.9514687461706547, 'colsample_bytree': 0.5539560556310217, 'reg_alpha': 0.6364081338181076, 'reg_lambda': 0.41984374703639193, 'min_child_weight': 10}. Best is trial 12 with value: 0.24692970603248954.
# [I 2025-03-03 18:16:36,333] Trial 20 finished with value: 0.2503403096818104 and parameters: {'n_estimators': 900, 'max_depth': 8, 'learning_rate': 0.16420441351407283, 'subsample': 0.780147967892888, 'colsample_bytree': 0.6897752224350673, 'reg_alpha': 0.8076965891365987, 'reg_lambda': 0.9820858027891292, 'min_child_weight': 6}. Best is trial 12 with value: 0.24692970603248954.
# [I 2025-03-03 18:21:32,752] Trial 21 finished with value: 0.24746269104885443 and parameters: {'n_estimators': 600, 'max_depth': 10, 'learning_rate': 0.19664491171054288, 'subsample': 0.9268635552333522, 'colsample_bytree': 0.6261375817628141, 'reg_alpha': 0.40119123737930246, 'reg_lambda': 0.14998898370185954, 'min_child_weight': 2}. Best is trial 12 with value: 0.24692970603248954.
# [I 2025-03-03 18:26:14,280] Trial 22 finished with value: 0.25007006375801977 and parameters: {'n_estimators': 400, 'max_depth': 12, 'learning_rate': 0.2831679448780226, 'subsample': 0.8593269884563592, 'colsample_bytree': 0.7515671956738306, 'reg_alpha': 0.052162569693474575, 'reg_lambda': 0.11894446176004075, 'min_child_weight': 2}. Best is trial 12 with value: 0.24692970603248954.
# [I 2025-03-03 18:33:15,025] Trial 23 finished with value: 0.24556096047403142 and parameters: {'n_estimators': 800, 'max_depth': 10, 'learning_rate': 0.09219203992461676, 'subsample': 0.9440038119184523, 'colsample_bytree': 0.6556610437910383, 'reg_alpha': 0.5921488001440582, 'reg_lambda': 0.27768888744961756, 'min_child_weight': 1}. Best is trial 23 with value: 0.24556096047403142.
# [I 2025-03-03 18:40:29,558] Trial 24 finished with value: 0.25199431482649215 and parameters: {'n_estimators': 800, 'max_depth': 10, 'learning_rate': 0.05097579689558989, 'subsample': 0.9502166808053162, 'colsample_bytree': 0.5733920342338781, 'reg_alpha': 0.5957693556583696, 'reg_lambda': 0.3082924490781144, 'min_child_weight': 4}. Best is trial 23 with value: 0.24556096047403142.
# [I 2025-03-03 18:48:32,484] Trial 25 finished with value: 0.24767538459998595 and parameters: {'n_estimators': 900, 'max_depth': 10, 'learning_rate': 0.08755118041431108, 'subsample': 0.71630655553754, 'colsample_bytree': 0.6683798581230639, 'reg_alpha': 0.576683814238834, 'reg_lambda': 0.20507646069442642, 'min_child_weight': 1}. Best is trial 23 with value: 0.24556096047403142.
# [I 2025-03-03 18:53:59,574] Trial 26 finished with value: 0.2496296629933239 and parameters: {'n_estimators': 700, 'max_depth': 9, 'learning_rate': 0.09922406268974025, 'subsample': 0.8197123585569821, 'colsample_bytree': 0.7546872638263773, 'reg_alpha': 0.7328385197170871, 'reg_lambda': 0.4046521113844631, 'min_child_weight': 3}. Best is trial 23 with value: 0.24556096047403142.
# [I 2025-03-03 18:59:10,494] Trial 27 finished with value: 0.2516515028676095 and parameters: {'n_estimators': 800, 'max_depth': 8, 'learning_rate': 0.14780696816442165, 'subsample': 0.9762987590301675, 'colsample_bytree': 0.5793732835658987, 'reg_alpha': 0.8591170116071729, 'reg_lambda': 0.6432115667687747, 'min_child_weight': 8}. Best is trial 23 with value: 0.24556096047403142.
# [I 2025-03-03 19:06:41,592] Trial 28 finished with value: 0.24655686674874133 and parameters: {'n_estimators': 600, 'max_depth': 12, 'learning_rate': 0.0378354564438446, 'subsample': 0.8766460938706729, 'colsample_bytree': 0.8236591764159968, 'reg_alpha': 0.41900844981450647, 'reg_lambda': 0.32412946163684925, 'min_child_weight': 4}. Best is trial 23 with value: 0.24556096047403142.
# [I 2025-03-03 19:17:41,848] Trial 29 finished with value: 0.2458011790729564 and parameters: {'n_estimators': 900, 'max_depth': 12, 'learning_rate': 0.035624787779876724, 'subsample': 0.6641370572117045, 'colsample_bytree': 0.8443417655261336, 'reg_alpha': 0.5674724331914014, 'reg_lambda': 0.5027668100812228, 'min_child_weight': 4}. Best is trial 23 with value: 0.24556096047403142.

# %%
best_params_cls = study_cls.best_params
print("Best parameters for classification:", best_params_cls)
# Out:
# Best parameters for classification: {'n_estimators': 800, 'max_depth': 10, 'learning_rate': 0.09219203992461676, 'subsample': 0.9440038119184523, 'colsample_bytree': 0.6556610437910383, 'reg_alpha': 0.5921488001440582, 'reg_lambda': 0.27768888744961756, 'min_child_weight': 1}

# %%
best_clf = xgb.XGBClassifier(**best_params_cls)
best_clf.fit(X_train, y_cls_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6556610437910383, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.09219203992461676,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=800, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_pred_cls = best_clf.predict(X_test)
acc_final = accuracy_score(y_cls_test, y_pred_cls)

# %%
print(f"Final Classification Accuracy: {acc_final}")
# Out:
# Final Classification Accuracy: 0.7544390395259686

# %%
# !pip install transformers accelerate torch sentencepiece --quiet

# %%
# !pip install -U bitsandbytes

# %%
from huggingface_hub import login
login()

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
import torch

# %%
model_name = "mistralai/Mistral-7B-Instruct-v0.1"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    load_in_8bit=True,  # Quantized model to save RAM
    device_map="auto"  # Uses GPU efficiently
)

# %%
llm_pipeline = pipeline("text-generation", model=model, tokenizer=tokenizer)

# %%
weather_conditions_map_rev = {v: k for k, v in weather_conditions_map.items()}  # Reverse mapping
weather_event_map_rev = {v: k for k, v in weather_event_map.items()}  # Reverse mapping for events

# %%
def generate_explanation(features, delay_pred, congestion_pred):
    # Correct decoding by using the reversed dictionary
    weather_condition = weather_conditions_map_rev.get(features["Weather_Conditions"], "Unknown")
    weather_event = weather_event_map_rev.get(features["Weather_Event"], "Unknown")

    prompt = f"""
    Given the following traffic data:
    - Weather Conditions: {weather_condition} (Event: {weather_event})
    - Temperature: {features['Temperature(F)']}°F
    - Wind Speed: {features['WindSpeed(mph)']} mph
    - Wind Direction: {features['WindDir']}
    - Visibility: {features['Visibility(mi)']} miles
    - Precipitation: {features['Precipitation(in)']} inches

    The model has predicted:
    - Delay: {delay_pred:.2f} minutes
    - Congestion Level: {"Fast" if congestion_pred == 0 else "Moderate" if congestion_pred == 1 else "Slow"}
    
    Explain why the delay and congestion level might be as predicted. Keep the explanation concise and suitable for traffic management personnel.
    """

    response = llm_pipeline(prompt, max_new_tokens=200)[0]["generated_text"]
    return response

# %%
sample_idx = 18
sample_features = df.iloc[sample_idx].to_dict()
sample_delay_pred = y_reg_pred[sample_idx]
sample_congestion_pred = y_cls_pred[sample_idx]

# %%
explanation = generate_explanation(sample_features, sample_delay_pred, sample_congestion_pred)
print(explanation)
